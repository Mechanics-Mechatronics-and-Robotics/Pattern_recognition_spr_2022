# %% [markdown]
# <a href="https://colab.research.google.com/github/Mechanics-Mechatronics-and-Robotics/Pattern_recognition_spr_2022/blob/main/Blood_flow_visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Установка и загрузка библиотек

# %%
# !pip install -Uqq fastbook # fast ai framework
# !pip install imageio
import fastbook
fastbook.setup_book()
# Out:
# Requirement already satisfied: imageio in /usr/local/lib/python3.7/dist-packages (2.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from imageio) (1.21.5)

# %%
from fastai.vision.all import*
import cv2
from google.colab.patches import cv2_imshow
import imageio

# %% [markdown]
# # Исходные данные

# %% [markdown]
# ## Настройки

# %% [markdown]
# Визуализация

# %%
fig_size = (5,5)
img_map = 'Greys'# 'Blues','Greys'...
# фрагмент изображения
leftx, lefty = 200, 500 # левая нижняя точка
h, w = 224, 224 # высота и ширина
scf = 1 # scale factor

# %% [markdown]
# Путь

# %%
path = Path('/content/gdrive/MyDrive/work/Fuzzy_logic_and_ML/Blood_count_Toy_dataset/lmg_f_16.02.2022_2p5_gc')
#path

# %% [markdown]
# Чтение содержимого

# %%
fnames = sorted(get_image_files(path))
fnames #, len(fnames), type(fnames)

# %% [markdown]
# # Вывод изображения на экран

# %% [markdown]
# С помощью библиотеки PIL (Python Image Library)

# %%
img = Image.open(fnames[0])
img

# %% [markdown]
#  С помощью numpy (np), opencv (cv2), matplotlib (plt)

# %%
img1 = np.uint8(cv2.imread(str(fnames[0])))
img1.shape, type(img1)
# Out:
# ((1000, 1000, 3), numpy.ndarray)

# %%
plt.figure(figsize = (fig_size[0]*3, fig_size[1]))
plt.subplot(1,3,1)
plt.imshow(img1[:,:,0])

plt.subplot(1,3,2)
plt.imshow(img1[:,:,1])

plt.subplot(1,3,3)
plt.imshow(img1[:,:,2])
